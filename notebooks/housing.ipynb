# %%
import pandas as pd 
import numpy as np 
import os
import json
import re

# %%
def extractLatLong(row):
    latLong = row["latLong"]
    if latLong == "{}" or len(latLong) <= 0:
        return np.nan, np.nan
    latLong = eval(latLong)
    lat = latLong["latitude"]
    long = latLong["longitude"]
    return lat, long

def extractBedPrice(row):
    if pd.notnull(row['units']):
        row['beds'] = row['units']['beds']
        row['unformattedPrice'] = row['units']['price']
        row['baths'] = 0
    return row

def process_zillow(df):
    usecols = [
        'units',
        'beds',
        'baths',
        'unformattedPrice',
        'address',
        'addressStreet',
        'addressState',
        'addressCity',
        'addressZipcode',
        'latLong'
    ]
    df = df[usecols]
    df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
    df['units'] = df['units'].apply(lambda x: np.nan if pd.isna(x) else eval(x))
    df = df.explode('units', ignore_index=True)
    df = df.apply(lambda row: extractBedPrice(row), axis=1, result_type="expand")
    df = df.drop(columns=["units", 'latLong'])
    df = df.rename(columns={
        'unformattedPrice': 'price',
        'addressStreet': 'street',
        'addressState': 'state',
        'addressCity': 'city',
        'addressZipcode': 'zipcode',
    })
    df['beds'] = df['beds'].astype(int)
    df['price'] = df['price'].apply(
        lambda x: int(x.replace('$', '').replace(',', '').replace('+', '')) if isinstance(x, str) else int(x)
    )
    return df

# %%
amenities_lst = ['community_amenities', 'amenities', 'Additional Upgraded and Premium Features', 'Upgraded Residence Amenities']

def parse_garden_amenity(amenities):
    return [amenity.strip() for amenity in amenities.strip().split('-') if (len(amenity.strip()) > 0) and ("offer" not in amenity.lower())]

def get_amenity_set(row):
    am, cm, adm, ura = [], [], [], []
    if row['amenities'] is not np.nan:
        am = parse_garden_amenity(row['amenities'])
    if row['community_amenities'] is not np.nan:
        cm = parse_garden_amenity(row['community_amenities'])
    if row['Additional Upgraded and Premium Features'] is not np.nan:
        adm = parse_garden_amenity(row['Additional Upgraded and Premium Features'])
    if row['Upgraded Residence Amenities'] is not np.nan:
        ura = parse_garden_amenity(row['Upgraded Residence Amenities'])
    combined_amenities = am + cm + adm + ura
    return set(combined_amenities)

def parse_garden_row(row):
    if row['baths'] is not np.nan:
        row['baths'] = parse_value(row['baths'])
    # If row['beds'] is not null
    if row['beds'] and row['beds'].lower() == 'studio':
        row['beds'] = 1
    else:
        row['beds'] = parse_value(row['beds'])
    if row['price'] is not np.nan:
        temp_price = row['price'].replace(',', '')
        row['price'] = parse_value(temp_price)
    if row['area'] is not np.nan:
        row['area'] = parse_value(row['area'])
    return row

def parse_value(string):
    pattern = r'(\d+)'
    match = re.search(pattern, string)
    if match:
        return int(match.group(1))
    else:
        return None

# %%
def process_garden(df):
    usecols = [
        'community_name',
        'community_address',
        'community_mobile',
        'overview_text',
        'floor_plan_name',
        'bath_num',
        'bed_num',
        'price_info',
        'area_info',
        'Apartment Amenities',
        'Community Amenities',
        'Additional Upgraded and Premium Features',
        'Upgraded Residence Amenities',
        'Appliances'
    ]
    df = df[usecols]
    df = df.dropna(axis=0, subset=['bath_num', 'bed_num'])
    df = df.rename(columns={
        'community_name': 'name',
        'community_address': 'address',
        'community_mobile': 'phone',
        'overview_text': 'description',
        'floor_plan_name': 'floor_plan',
        'bath_num': 'baths',
        'bed_num': 'beds',
        'price_info': 'price',
        'area_info': 'area',
        'Apartment Amenities': 'amenities',
        'Community Amenities': 'community_amenities',
    })
    df['combined_amenities'] = df.apply(lambda row: get_amenity_set(row), axis=1)
    df['Appliances'] = (
        df['Appliances']
            .apply(lambda x: set(parse_garden_amenity(x)) if ((x is not np.nan) and (len(x.strip()) > 0)) else np.nan)
    )
    df = df.drop(columns=[
        'amenities',
        'community_amenities',
        'Additional Upgraded and Premium Features',
        'Upgraded Residence Amenities'
    ])
    df = df.apply(lambda row: parse_garden_row(row), axis=1, result_type="expand")
    return df

# %%
data_dir = "../data/housing/raw"
data_files = os.listdir(data_dir)
zillows = []
gardens = []
for filename in data_files:
    full_path = os.path.join(data_dir, filename)
    if "zillow" in filename:
        new_df = process_zillow(pd.read_csv(full_path))
        zillows.append(new_df)
    elif "garden" in filename:
        new_df = process_garden(pd.read_csv(full_path))
        gardens.append(new_df)
# Out:
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['units'] = df['units'].apply(lambda x: np.nan if pd.isna(x) else eval(x))
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['units'] = df['units'].apply(lambda x: np.nan if pd.isna(x) else eval(x))
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['lat', 'long']] = df[["latLong"]].apply(lambda x: extractLatLong(x), axis=1, result_type="expand")
# /var/folders/ml/3qpj1_6x4fj_gcl3ztrny2700000gn/T/ipykernel_16100/2764685260.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['units'] = df['units'].apply(lambda x: np.nan if pd.isna(x) else eval(x))

# %%
zillow_df = pd.concat(zillows, ignore_index=True)
garden_df = pd.concat(gardens, ignore_index=True)
zillow_df.drop_duplicates(inplace=True)

# %%
garden_df = garden_df.rename(columns={
    'area': 'sqft',
    'Appliances': 'appliances',
    'combined_amenities': 'amenities',
})

# %%
zillow_df.to_json("../data/housing/processed/zillow.json", orient="records")
garden_df.to_json("../data/housing/processed/garden.json", orient="records")

# %%
zillow_df = zillow_df.rename(columns={'long': 'lon'})
zillow_df.to_json("../data/housing/processed/zillow.json", orient="records")

# %%
zillow_df.dtypes
# Out:
# beds         int64
# baths      float64
# price        int64
# address     object
# street      object
# state       object
# city        object
# zipcode      int64
# lat        float64
# lon        float64
# dtype: object

# %%
garden_df.dtypes
# Out:
# name            object
# address         object
# phone           object
# description     object
# floor_plan      object
# baths            int64
# beds             int64
# price          float64
# sqft             int64
# appliances      object
# amenities       object
# dtype: object

# %%
cleaned_df = pd.read_csv("../data/housing/raw/final_df.csv").drop(columns=['Unnamed: 0', 'url', 'post_id'])
craigslist = cleaned_df[cleaned_df['from'] == 'craigslist'].dropna(axis=1, how='all').reset_index(drop=True)
apartment = cleaned_df[cleaned_df['from'] == 'apartment'].dropna(axis=1, how='all').reset_index(drop=True)

# %%
cl_json = pd.read_json('../data/housing/processed/craigslist.json')
cl_json = cl_json.loc[~cl_json['baths'].isin(['shared', 'split'])]
cl_json['baths'] = cl_json['baths'].astype(float)

# %%
cl_json['baths'].unique()
# Out:
# array([2. , 1. , 3. , 2.5, 3.5, 1.5, 4.5, 4. ])

# %%
cl_json.dtypes
# Out:
# post_id                    int64
# beds                       int64
# baths                    float64
# price                      int64
# sqft                       int64
# houseType                 object
# rentPeriod                object
# parking                   object
# laundry                   object
# pets                      object
# smoking                   object
# air conditioning          object
# wheelchair accessible     object
# EV charging               object
# furnished                 object
# lat                      float64
# lon                      float64
# dtype: object

# %%
cl_json.to_json('../data/housing/processed/craigslist.json', orient='records')

# %%
garden = pd.read_csv('../data/housing/raw/garden_community-2022-07-05.csv')
garden.head()
# Out:
#    Unnamed: 0         community_name                 community_address  \
# 0           0  360 Luxury Apartments  9065 Sydney Court, San Diego, CA
# 1           1  360 Luxury Apartments  9065 Sydney Court, San Diego, CA
# 2           2  360 Luxury Apartments  9065 Sydney Court, San Diego, CA
# 3           3  360 Luxury Apartments  9065 Sydney Court, San Diego, CA
# 4           4  360 Luxury Apartments  9065 Sydney Court, San Diego, CA
#
#   community_mobile                                      overview_text  \
# 0   (858) 358-7681  Up to First Month Free!*  *All prices and spec...
# 1   (858) 358-7681  Up to First Month Free!*  *All prices and spec...
# 2   (858) 358-7681  Up to First Month Free!*  *All prices and spec...
# 3   (858) 358-7681  Up to First Month Free!*  *All prices and spec...
# 4   (858) 358-7681  Up to First Month Free!*  *All prices and spec...
#
#     floor_plan_name bath_num    bed_num        price_info           area_info  \
# 0           Compass   1 Bath     Studio  $2,725 - $3,225     662 - 743 sq.ft.
# 1            Escape   1 Bath  1 Bedroom  $3,135 - $3,610           874 sq.ft.
# 2  Escape with Loft   1 Bath  1 Bedroom  $3,610 - $3,960   1016 - 1105 sq.ft.
# 3            Evolve   1 Bath  1 Bedroom  $3,135 - $3,410     880 - 909 sq.ft.
# 4  Evolve with Loft   1 Bath  1 Bedroom            $3,610         1028 sq.ft.
#
#    ... Upgraded Residence Amenities Appliances Community Residence Features  \
# 0  ...                          NaN        NaN       NaN                NaN
# 1  ...                          NaN        NaN       NaN                NaN
# 2  ...                          NaN        NaN       NaN                NaN
# 3  ...                          NaN        NaN       NaN                NaN
# 4  ...                          NaN        NaN       NaN                NaN
# [La Jolla Blue Apartments](https://www.apartmen...  Community Amenities, Pool, Fitness Center, Clu...
#
#                                                                                                Images  \
# [La Scala Apartments](https://www.apartments.co...  ![Primary Photo - La Scala Apartments](https:/...
# [La Jolla International Gardens](https://www.ap...  ![Primary Photo - La Jolla International Garde...
# [Costa Verde Village](https://www.apartments.co...  ![Primary Photo - Costa Verde Village](https:/...
# [LUX by Garden](https://www.apartments.com/lux-...  ![Primary Photo - LUX by Garden](https://image...
# [La Jolla Blue Apartments](https://www.apartmen...  ![Primary Photo - La Jolla Blue Apartments](ht...
#
#                                                                                           Description
# [La Scala Apartments](https://www.apartments.co...  About La Scala Apartments\nLa Scala offers lux...
# [La Jolla International Gardens](https://www.ap...  About La Jolla International Gardens\nAt La Jo...
# [Costa Verde Village](https://www.apartments.co...  About Costa Verde Village\nIf you are looking ...
# [LUX by Garden](https://www.apartments.com/lux-...  About LUX by Garden\nLUX by Garden is the most...
# [La Jolla Blue Apartments](https://www.apartmen...  About La Jolla Blue Apartments\nWelcome home t...

# %%
zillow = pd.read_csv('../data/housing/raw/zillow-2022-07-05.csv')
zillow.head()
# Out:
#                     zpid                     id         lotId  \
# 0   32.86568--117.235725   32.86568--117.235725  1.001554e+09
# 1   32.841976--117.27955   32.841976--117.27955  1.001635e+09
# 2             2066751394             2066751394           NaN
# 3  32.841022--117.275635  32.841022--117.275635           NaN
# 4               16857530               16857530           NaN
#
#                                               imgSrc  hasImage statusType  \
# 0  https://photos.zillowstatic.com/fp/c16331bf1be...      True   FOR_RENT
# 1  https://photos.zillowstatic.com/fp/025e0ccd6d5...      True   FOR_RENT
# 2  https://photos.zillowstatic.com/fp/69042eebea3...      True   FOR_RENT
# 3  https://photos.zillowstatic.com/fp/f92d733361d...      True   FOR_RENT
# 4  https://photos.zillowstatic.com/fp/c716e2f7c26...      True   FOR_RENT
#
#                                 statusText  \
# 0                 Solazzo Apartments Homes
# 1  Ocean House on Prospect Apartment Homes
# 2                       Apartment for rent
# 3                                 For Rent
# 4                       Apartment for rent
#
#                                            detailUrl  \
# 0    /b/solazzo-apartments-homes-la-jolla-ca-5Xk5YK/
# 1  /b/ocean-house-on-prospect-apartment-homes-la-...
# 2  https://www.zillow.com/homedetails/7623-Eads-A...
# 3           /b/La-Jolla-CA/32.841022,-117.275635_ll/
# 4  https://www.zillow.com/homedetails/2205-Camini...
#
#                                              latLong  \
# 0   {'latitude': 32.86568, 'longitude': -117.235725}
# 1   {'latitude': 32.841976, 'longitude': -117.27955}
# 2   {'latitude': 32.842457, 'longitude': -117.27549}
# 3  {'latitude': 32.841022, 'longitude': -117.275635}
# 4   {'latitude': 32.81866, 'longitude': -117.234184}
#
#                                                units  ... isUserClaimingOwner  \
# 0                [{'price': '$3,165+', 'beds': '1'}]  ...                 NaN
# 1  [{'price': '$5,340+', 'beds': '1'}, {'price': ...  ...                 NaN
# 2                                                NaN  ...               False
# 3                [{'price': '$5,975+', 'beds': '3'}]  ...                 NaN
# 4                                                NaN  ...               False
#
#    isUserConfirmedClaim    pgapt     sgapt  zestimate  \
# 0                   NaN      NaN       NaN        NaN
# 1                   NaN      NaN       NaN        NaN
# 2                 False  ForRent  For Rent        NaN
# 3                   NaN      NaN       NaN        NaN
# 4                 False  ForRent  For Rent  1304800.0
#
#   shouldShowZestimateAsPrice hasVideo isHomeRec  hasAdditionalAttributions  \
# 0                        NaN      NaN       NaN                        NaN
# 1                        NaN      NaN       NaN                        NaN
# 2                      False    False     False                      False
# 3                        NaN      NaN       NaN                        NaN
# 4                      False    False     False                      False
#
#       availabilityDate
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4  2022-09-01 00:00:00
#
# [5 rows x 46 columns]

# %%
craigslist = craigslist.loc[~craigslist['num_baths'].isin(['shared', 'split'])]
craigslist = craigslist.drop(columns=['from', 'tf_idf_words'])
craigslist = craigslist.rename(columns={
    'num_baths': 'baths',
    'num_beds': 'beds',
    'price': 'price',
    'area': 'area',
    )
# Out:
#                       post_date  num_beds num_baths   price  \
# 0     2022-02-05 19:56:55+00:00       3.0         2  3587.0
# 1     2022-02-09 16:14:22+00:00       1.0         1  2900.0
# 2     2022-02-09 16:32:09+00:00       1.0         1  2550.0
# 3     2022-02-09 16:32:48+00:00       2.0         2  2875.0
# 4     2022-02-09 16:37:12+00:00       0.0         1  1745.0
# ...                         ...       ...       ...     ...
# 2620  2022-03-27 09:47:43+00:00       2.0         2  1500.0
# 2621  2022-03-27 09:50:40+00:00       1.0         1  1176.0
# 2622  2022-03-27 09:53:56+00:00       1.0         1  1120.0
# 2623  2022-03-27 10:03:59+00:00       1.0         1  1133.0
# 2624  2022-03-27 10:07:12+00:00       1.0         1  1162.0
#
#                         address    sqft  \
# 0             3889 Midway Drive  1050.0
# 1              7039 Charmant Dr    -1.0
# 2          4956 Cape May Avenue   900.0
# 3            4975 Del Monte Ave   800.0
# 4     2185 Chatsworth Boulevard    -1.0
# ...                         ...     ...
# 2620      12557 Ruette Alliante    -1.0
# 2621                        NaN    -1.0
# 2622                        NaN    -1.0
# 2623                        NaN    -1.0
# 2624                        NaN    -1.0
#
#                                                features  \
# 0     cats are OK - purrr, dogs are OK - wooof, apar...
# 1                       apartment, w/d in unit, carport
# 2     cats are OK - purrr, dogs are OK - wooof, apar...
# 3     cats are OK - purrr, apartment, laundry on sit...
# 4     cats are OK - purrr, apartment, laundry on sit...
# ...                                                 ...
# 2620                                                NaN
# 2621  cats are OK - purrr, dogs are OK - wooof, furn...
# 2622  cats are OK - purrr, dogs are OK - wooof, furn...
# 2623  cats are OK - purrr, dogs are OK - wooof, furn...
# 2624  cats are OK - purrr, dogs are OK - wooof, furn...
#
#                      scrape_date                  full_address  houseType  \
# 0     2022-03-27 04:45:44.347396          3889 Midway Drive,CA  apartment
# 1     2022-03-27 07:22:10.741597           7039 Charmant Dr,CA  apartment
# 2     2022-03-27 04:57:21.315450       4956 Cape May Avenue,CA  apartment
# 3     2022-03-27 05:03:22.265853         4975 Del Monte Ave,CA  apartment
# 4     2022-03-27 07:47:25.414411  2185 Chatsworth Boulevard,CA  apartment
# ...                          ...                           ...        ...
# 2620  2022-03-27 04:58:55.887786      12557 Ruette Alliante,CA        NaN
# 2621  2022-03-27 04:21:36.437093                           NaN  apartment
# 2622  2022-03-27 07:30:38.802107                           NaN  apartment
# 2623  2022-03-27 06:01:41.005551                           NaN  apartment
# 2624  2022-03-27 06:16:08.980072                           NaN  apartment
#
#       ...             parking          laundry                 pets  \
# 0     ...  off-street parking      w/d in unit  cats are OK - purrr
# 1     ...             carport      w/d in unit                  NaN
# 2     ...  off-street parking  laundry in bldg  cats are OK - purrr
# 3     ...  off-street parking  laundry on site  cats are OK - purrr
# 4     ...  off-street parking  laundry on site  cats are OK - purrr
# ...   ...                 ...              ...                  ...
# 2620  ...                 NaN              NaN                  NaN
# 2621  ...     attached garage      w/d in unit  cats are OK - purrr
# 2622  ...     attached garage      w/d in unit  cats are OK - purrr
# 2623  ...     attached garage      w/d in unit  cats are OK - purrr
# 2624  ...     attached garage      w/d in unit  cats are OK - purrr
#
#          smoking air conditioning wheelchair accessible EV charging  \
# 0            NaN              NaN                   NaN         NaN
# 1            NaN              NaN                   NaN         NaN
# 2     no smoking              NaN                   NaN         NaN
# 3     no smoking              NaN                   NaN         NaN
# 4     no smoking              NaN                   NaN         NaN
# ...          ...              ...                   ...         ...
# 2620         NaN              NaN                   NaN         NaN
# 2621  no smoking              NaN                   NaN         NaN
# 2622  no smoking              NaN                   NaN         NaN
# 2623  no smoking              NaN                   NaN         NaN
# 2624         NaN              NaN                   NaN         NaN
#
#       furnished                                        tfidf_words        from
# 0           NaN  ['onsite', 'unitsindoor', 'accessprofessional'...  craigslist
# 1           NaN  ['blue', 'per', '3vd4ntbq', 'fansvaulted', 'st...  craigslist
# 2           NaN         ['cape', 'elan', 'palms', 'pier', 'beach']  craigslist
# 3           NaN  ['coco', 'palms', 'elan', 'elancocopalms', 'pi...  craigslist
# 4           NaN    ['loma', 'highlands', 'elan', 'round', 'needs']  craigslist
# ...         ...                                                ...         ...
# 2620        NaN    ['ample', 'getting', 'both', 'onepaseo', 'mar']  craigslist
# 2621  furnished  ['laptop', 'udio', 'saving', 'utensils', 'cook...  craigslist
# 2622  furnished  ['bayfront', 'dated', 'lyra', 'caesarstone', '...  craigslist
# 2623  furnished         ['pardee', 'clubs', 'tha', 'phr', 'bosch']  craigslist
# 2624  furnished  ['sabbatical', 'points', 'discriminating', 'ra...  craigslist
#
# [2621 rows x 21 columns]

# %%
apartment_df = pd.read_json("../data/housing/processed/apartment.json")
apartment_df = apartment_df.drop(columns=['from'])
apartment_df.dtypes
# Out:
# beds              float64
# baths             float64
# price             float64
# sqft              float64
# name               object
# Contact           float64
# address            object
# One Time Fees      object
# Transportation     object
# Education          object
# Pet Policy         object
# Parking            object
# Amenities          object
# Images             object
# description        object
# floorplan          object
# price_range        object
# dtype: object

# %%
apartment_df.to_json("../data/housing/processed/apartment.json", orient="records")

# %%
craigslist = pd.read_json("../data/housing/craigslist.json")
garden_df = pd.read_json("../data/housing/garden.json")
zillow_df = pd.read_json("../data/housing/zillow.json")

# %%
data_files
# Out:
# ['zillow-2022-07-31.csv',
#  '.DS_Store',
#  'garden_community-2022-05-26.csv',
#  'garden_community-2022-05-27.csv',
#  'apartment_com-2022-07-31.csv',
#  'garden_community-2022-07-31.csv',
#  'apartment_com-2022-07-04.csv',
#  'garden_community-2022-07-04.csv',
#  'garden_community-2022-07-05.csv',
#  'apartment_com-2022-07-05.csv',
#  'zillow-2022-07-05.csv',
#  'zillow-2022-07-04.csv']
